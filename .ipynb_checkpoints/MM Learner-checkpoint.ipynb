# %%
from spline_learner_poe4d_MM import *
import matplotlib.pyplot as plt
# %matplotlib inline
spl = SplineLearnerPOE_4D(use_mm = 0, NPTSPERSAMP = 5, DT = .6)
spl.run(gibbs_steps = 500, train_x = False, train_f2 = False)
# Out:
# > /Users/jendawk/Documents/GeorgTravisRot/POE_learner/helper.py(200)plot_f1()
# -> g1_mean = np.reshape(mu_theta@bmat_plot.T, xplot.shape, order = 'F')
# (Pdb) c
# Step 0
# Meas Var:0.0005555555555555556
# Proc Var:6.666666666666667
# POE Var:6.666666666666667
# > /Users/jendawk/Documents/GeorgTravisRot/POE_learner/helper.py(200)plot_f1()
# -> g1_mean = np.reshape(mu_theta@bmat_plot.T, xplot.shape, order = 'F')
# (Pdb) c
# Step 0
# Meas Var:0.0005555555555555556
# Proc Var:7.377836377712338
# POE Var:7.306718832282618
# Step 0 Complete
# Step 1 Complete
# Step 2 Complete
# Step 3 Complete
# Step 4 Complete
# Step 5 Complete
# Step 6 Complete
# Step 7 Complete
# Step 8 Complete
# Step 9 Complete
# > /Users/jendawk/Documents/GeorgTravisRot/POE_learner/helper.py(200)plot_f1()
# -> g1_mean = np.reshape(mu_theta@bmat_plot.T, xplot.shape, order = 'F')

# %%
spl.true_b
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
spl.states.shape[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-45764835a443> in <module>
# ----> 1 spl.states.shape[-1]
#
# NameError: name 'spl' is not defined

# %%
f1 = np.reshape(spl.f1vec[0],(20,spl.num_bugs), order = 'F')

# %%
spl.f1vec[0].shape
# Out:
# (60,)

# %%
for i in range(3):
    plt.plot(spl.states[:-1,i,0],spl.states[1:,i,0],label = 'states')
    plt.plot(spl.states[:-1,i,0],f1[:,i],label  = 'f1')
    plt.legend()
    plt.show()
