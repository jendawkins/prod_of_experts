# %%
from spline_learner_poe4d_MM import *
spl = SplineLearnerPOE_4D(NPTSPERSAMP = 100, DT = .01)
# Out:
# /Users/jendawk/Documents/GeorgTravisRot/POE_learner/spline_learner_poe4d_MM.py:79: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   self.true_betas = np.linalg.lstsq(self.true_bmat1, Y_est)[0]

# %%
from spline_learner_poe4d_MM import *
import matplotlib.pyplot as plt
# %matplotlib inline
spl = SplineLearnerPOE_4D(use_mm = 0, NPTSPERSAMP = 100, DT = .01)
spl.run(gibbs_steps = 500)
# Out:
# /Users/jendawk/Documents/GeorgTravisRot/POE_learner/spline_learner_poe4d_MM.py:215: RuntimeWarning: overflow encountered in exp
#   prob_keep = np.exp(np.sum(num,0) - np.sum(dem,0))
# /Users/jendawk/Documents/GeorgTravisRot/POE_learner/spline_learner_poe4d_MM.py:241: RuntimeWarning: overflow encountered in exp
#   prob_keep = np.exp(np.sum(num, 0) - np.sum(dem, 0))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0bab55ef4bca> in <module>
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 spl = SplineLearnerPOE_4D(use_mm = 0, NPTSPERSAMP = 100, DT = .01)
# ----> 5 spl.run(gibbs_steps = 500)
#
# ~/Documents/GeorgTravisRot/POE_learner/spline_learner_poe4d_MM.py in run(self, gibbs_steps, train_x, train_f1, train_f2, train_var, plot)
#     373                 # Train X
#     374                 if train_x:
# ...

# %%
spl.states.shape
# Out:
# (101, 3, 2)

# %%
f1 = np.reshape(spl.f1vec[0],(20,spl.num_bugs), order = 'F')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-df2f5af4ce7a> in <module>
# ----> 1 f1 = np.reshape(spl.f1vec[0],(20,spl.num_bugs), order = 'F')
#
# AttributeError: 'SplineLearnerPOE_4D' object has no attribute 'f1vec'

# %%
os.path.exists('test')
# Out:
# True

# %%
import os
os.mkdir('test')

# %%
plt.plot(spl.states[:,1,1])
plt.savefig('test/test.png')

# %%
for i in range(3):
    plt.plot(spl.states[:-1,i,0],spl.states[1:,i,0],label = 'states')
    plt.plot(spl.states[:-1,i,0],f1[:,i],label  = 'f1')
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d7fcc641ca22> in <module>
#       1 for i in range(3):
#       2     plt.plot(spl.states[:-1,i,0],spl.states[1:,i,0],label = 'states')
# ----> 3     plt.plot(spl.states[:-1,i,0],f1[:,i],label  = 'f1')
#       4     plt.legend()
#       5     plt.savefig('test')
#
# NameError: name 'f1' is not defined
